# %% [markdown]
# # Birdie Model(Default Pretraining)

# %% [markdown]
# ## Data Loader

# %%
import os
import torch
import torchaudio
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F

class AudioDataset(Dataset):
    def __init__(self, data_dir, sample_rate=16000, duration=5):
        self.file_paths = [os.path.join(data_dir, f) for f in os.listdir(data_dir) if f.endswith('.wav')]
        self.sample_rate = sample_rate
        self.samples = sample_rate * duration

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        waveform, sr = torchaudio.load(self.file_paths[idx])
        waveform = torchaudio.functional.resample(waveform, orig_freq=sr, new_freq=self.sample_rate)
        waveform = waveform.mean(dim=0)
        if waveform.size(0) < self.samples:
            waveform = torch.nn.functional.pad(waveform, (0, self.samples - waveform.size(0)))
        else:
            waveform = waveform[:self.samples]
        return waveform

# %%
# Your dataset path
dataset_path = "data/genres_original/classical"

# Load dataset
dataset = AudioDataset(data_dir=dataset_path)
dataloader = DataLoader(dataset, batch_size=8, shuffle=True)

# (Optional) Plot a sample
waveform = dataset[0]
plt.plot(waveform.numpy())
plt.title("Sample Waveform")
plt.show()

# %% [markdown]
# ## Birdie Model (Simple SSM-style VAE)

# %%
import torch.nn as nn
import torch.nn.functional as F

class BirdieVAE(nn.Module):
    def __init__(self, input_dim=80000, hidden_dim=512, latent_dim=128):
        super(BirdieVAE, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim)
        )
        self.fc_mu = nn.Linear(hidden_dim, latent_dim)
        self.fc_logvar = nn.Linear(hidden_dim, latent_dim)
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim),
            nn.Tanh()
        )

    def encode(self, x):
        h = self.encoder(x)
        return self.fc_mu(h), self.fc_logvar(h)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z):
        return self.decoder(z)

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar

# %% [markdown]
# ## Train Function

# %%
def vae_loss(recon_x, x, mu, logvar):
    recon_loss = F.mse_loss(recon_x, x, reduction='sum')
    kld = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return recon_loss + kld

def train(model, dataloader, epochs=10, lr=1e-3):
    model.train()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    for epoch in range(epochs):
        total_loss = 0
        for batch in dataloader:
            batch = batch.to(torch.float32).to('cpu')
            batch = batch.view(batch.size(0), -1)
            recon, mu, logvar = model(batch)
            loss = vae_loss(recon, batch, mu, logvar)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(f"Epoch {epoch+1}, Loss: {total_loss:.2f}")

# %%
model = BirdieVAE(input_dim=16000 * 5)  # 5 seconds of audio at 16kHz
train(model, dataloader, epochs=10)
# Out:
# Epoch 1, Loss: 268162.96
# Epoch 2, Loss: 447096.10
# Epoch 3, Loss: 135092.80
# Epoch 4, Loss: 76870.48
# Epoch 5, Loss: 58254.52
# Epoch 6, Loss: 51088.22
# Epoch 7, Loss: 48654.98
# Epoch 8, Loss: 45372.71
# Epoch 9, Loss: 81564.38
# Epoch 10, Loss: 52640.98

# %% [markdown]
# ## Generate Sample

# %%
def generate_sample(model, output_path='generated_default.wav', sr=16000):
    model.eval()
    with torch.no_grad():
        z = torch.randn(1, 128)
        sample = model.decode(z).view(-1).cpu().numpy()
        torchaudio.save(output_path, torch.tensor([sample]), sample_rate=sr)

# Call it:
generate_sample(model, output_path='generated_default.wav')

# %%
from IPython.display import Audio

# Play the generated audio
Audio("generated_default.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Selective Copying

# %%
def selective_copying_loss(pred, target, mask):
    # Only compute loss where mask == 1 (i.e., where copying is required)
    return F.mse_loss(pred[mask], target[mask])

# %%
class CopyingDataset(AudioDataset):
    def __getitem__(self, idx):
        waveform = super().__getitem__(idx)
        mask = torch.zeros_like(waveform, dtype=torch.bool)
        # Randomly choose a segment to copy (e.g., middle 1 sec)
        start = waveform.shape[0] // 3
        end = start + waveform.shape[0] // 5
        mask[start:end] = 1
        target = waveform.clone()
        waveform[start:end] = 0  # zero-out copy span
        return waveform, target, mask

# %%
def train_selective_copying(model, dataloader, epochs=10, lr=1e-3):
    model.train()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    for epoch in range(epochs):
        total_loss = 0
        for batch, target, mask in dataloader:
            batch = batch.view(batch.size(0), -1)
            target = target.view(target.size(0), -1)
            mask = mask.view(mask.size(0), -1)
            recon, mu, logvar = model(batch)
            loss = selective_copying_loss(recon, target, mask)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(f"[Selective Copying] Epoch {epoch+1}, Loss: {total_loss:.2f}")

# %%
# Step 1: Load Dataset
copy_dataset = CopyingDataset(data_dir="data/genres_original/classical", sample_rate=16000, duration=5)
copy_dataloader = DataLoader(copy_dataset, batch_size=8, shuffle=True)

# Step 2: Initialize the Model
input_dim = 16000 * 5  # 5 seconds at 16kHz
model = BirdieVAE(input_dim=input_dim, hidden_dim=512, latent_dim=128)

# Step 3: Train with Selective Copying
train_selective_copying(model, copy_dataloader, epochs=10)
# Out:
# [Selective Copying] Epoch 1, Loss: 0.41
# [Selective Copying] Epoch 2, Loss: 0.30
# [Selective Copying] Epoch 3, Loss: 0.09
# [Selective Copying] Epoch 4, Loss: 0.07
# [Selective Copying] Epoch 5, Loss: 0.05
# [Selective Copying] Epoch 6, Loss: 0.05
# [Selective Copying] Epoch 7, Loss: 0.05
# [Selective Copying] Epoch 8, Loss: 0.05
# [Selective Copying] Epoch 9, Loss: 0.05
# [Selective Copying] Epoch 10, Loss: 0.05

# %%
def generate_sample_selective(model, output_path='generated_selective.wav', sr=16000):
    model.eval()
    with torch.no_grad():
        z = torch.randn(1, 128)  # match latent_dim
        sample = model.decode(z).view(-1).cpu()

        # Optional: normalize audio
        sample = sample / sample.abs().max()

        # Save as WAV
        torchaudio.save(output_path, sample.unsqueeze(0), sample_rate=sr)

# %%
# Generate audio sample
generate_sample_selective(model, output_path='generated_selective.wav')

# %%
from IPython.display import Audio

# Play the generated audio
Audio("generated_default.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# --- Install dependencies (run only once) ---
# !pip install torchaudio librosa numpy matplotlib

# --- Imports ---
import os
import torch
import torchaudio
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
from IPython.display import Audio

# --- Dataset Classes ---
class AudioDataset(Dataset):
    def __init__(self, data_dir, sample_rate=16000, duration=5):
        self.file_paths = [os.path.join(data_dir, f) for f in os.listdir(data_dir) if f.endswith('.wav')]
        self.sample_rate = sample_rate
        self.samples = sample_rate * duration

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        waveform, sr = torchaudio.load(self.file_paths[idx])
        waveform = torchaudio.functional.resample(waveform, orig_freq=sr, new_freq=self.sample_rate)
        waveform = waveform.mean(dim=0)
        if waveform.size(0) < self.samples:
            waveform = torch.nn.functional.pad(waveform, (0, self.samples - waveform.size(0)))
        else:
            waveform = waveform[:self.samples]
        return waveform

class CopyingDataset(AudioDataset):
    def __getitem__(self, idx):
        waveform = super().__getitem__(idx)
        mask = torch.zeros_like(waveform, dtype=torch.bool)
        start = waveform.shape[0] // 3
        end = start + waveform.shape[0] // 5
        mask[start:end] = 1
        target = waveform.clone()
        waveform[start:end] = 0
        return waveform, target, mask

class AutoencodingDataset(AudioDataset):
    def __getitem__(self, idx):
        waveform = super().__getitem__(idx)
        noisy = waveform.clone()
        mask_ratio = 0.1
        mask_size = int(len(waveform) * mask_ratio)
        start = torch.randint(0, len(waveform) - mask_size, (1,))
        noisy[start:start+mask_size] = 0
        return noisy, waveform

# --- Model: Bidirectional Birdie VAE ---
class BirdieVAE(nn.Module):
    def __init__(self, input_dim=80000, hidden_dim=512, latent_dim=128):
        super(BirdieVAE, self).__init__()
        self.encoder_fwd = nn.Sequential(
            nn.Linear(input_dim, hidden_dim), nn.ReLU(), nn.Linear(hidden_dim, hidden_dim)
        )
        self.encoder_rev = nn.Sequential(
            nn.Linear(input_dim, hidden_dim), nn.ReLU(), nn.Linear(hidden_dim, hidden_dim)
        )
        self.fc_mu = nn.Linear(hidden_dim * 2, latent_dim)
        self.fc_logvar = nn.Linear(hidden_dim * 2, latent_dim)
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim), nn.ReLU(), nn.Linear(hidden_dim, input_dim), nn.Tanh()
        )

    def encode(self, x):
        h_fwd = self.encoder_fwd(x)
        h_rev = self.encoder_rev(torch.flip(x, dims=[1]))
        h = torch.cat((h_fwd, h_rev), dim=1)
        return self.fc_mu(h), self.fc_logvar(h)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z):
        return self.decoder(z)

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar

# --- Loss & Train Functions ---
def vae_loss(recon_x, x, mu, logvar):
    recon_loss = F.mse_loss(recon_x, x, reduction='sum')
    kld = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return recon_loss + kld

def train(model, dataloader, epochs=10, lr=1e-3):
    model.train()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    for epoch in range(epochs):
        total_loss = 0
        for batch in dataloader:
            batch = batch.to(torch.float32).to('cpu')
            batch = batch.view(batch.size(0), -1)
            recon, mu, logvar = model(batch)
            loss = vae_loss(recon, batch, mu, logvar)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(f"[Default VAE] Epoch {epoch+1}, Loss: {total_loss:.2f}")

def selective_copying_loss(pred, target, mask):
    return F.mse_loss(pred[mask], target[mask])

def train_selective_copying(model, dataloader, epochs=10, lr=1e-3):
    model.train()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    for epoch in range(epochs):
        total_loss = 0
        for batch, target, mask in dataloader:
            batch = batch.view(batch.size(0), -1)
            target = target.view(target.size(0), -1)
            mask = mask.view(mask.size(0), -1)
            recon, mu, logvar = model(batch)
            loss = selective_copying_loss(recon, target, mask)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(f"[Selective Copying] Epoch {epoch+1}, Loss: {total_loss:.2f}")

def train_autoencoding(model, dataloader, epochs=10, lr=1e-3):
    model.train()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    for epoch in range(epochs):
        total_loss = 0
        for noisy, target in dataloader:
            noisy = noisy.view(noisy.size(0), -1)
            target = target.view(target.size(0), -1)
            recon, mu, logvar = model(noisy)
            loss = vae_loss(recon, target, mu, logvar)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(f"[Autoencoding] Epoch {epoch+1}, Loss: {total_loss:.2f}")

# --- Sample Generation ---
def generate_sample(model, output_path='generated.wav', sr=16000):
    model.eval()
    with torch.no_grad():
        z = torch.randn(1, 128)
        sample = model.decode(z).view(-1).cpu()
        sample = sample / sample.abs().max()
        torchaudio.save(output_path, sample.unsqueeze(0), sample_rate=sr)
        return Audio(output_path)

# --- Run (example: default training) ---
data_path = "data/genres_original/classical"
input_dim = 16000 * 5
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torchaudio in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (0.12.1+cu113)
# Requirement already satisfied: librosa in /home/vsaluja2/.local/lib/python3.9/site-packages (0.10.1)
# Requirement already satisfied: numpy in /home/vsaluja2/.local/lib/python3.9/site-packages (1.26.2)
# Requirement already satisfied: matplotlib in /home/vsaluja2/.local/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: torch==1.12.1 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from torchaudio) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /home/vsaluja2/.local/lib/python3.9/site-packages (from torch==1.12.1->torchaudio) (4.12.2)
# Requirement already satisfied: audioread>=2.1.9 in /home/vsaluja2/.local/lib/python3.9/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /home/vsaluja2/.local/lib/python3.9/site-packages (from librosa) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from librosa) (1.1.1)
# Requirement already satisfied: joblib>=0.14 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: decorator>=4.3.0 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /home/vsaluja2/.local/lib/python3.9/site-packages (from librosa) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /home/vsaluja2/.local/lib/python3.9/site-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.0 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from librosa) (1.6.0)
# Requirement already satisfied: soxr>=0.3.2 in /home/vsaluja2/.local/lib/python3.9/site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in /home/vsaluja2/.local/lib/python3.9/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /home/vsaluja2/.local/lib/python3.9/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vsaluja2/.local/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from matplotlib) (4.31.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from matplotlib) (1.4.0)
# Requirement already satisfied: packaging>=20.0 in /home/vsaluja2/.local/lib/python3.9/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from matplotlib) (9.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/vsaluja2/.local/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/vsaluja2/.local/lib/python3.9/site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in /home/vsaluja2/.local/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/vsaluja2/.local/lib/python3.9/site-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: appdirs>=1.3.0 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /home/vsaluja2/.local/lib/python3.9/site-packages (from pooch>=1.0->librosa) (2.32.3)
# Requirement already satisfied: six>=1.5 in /home/vsaluja2/.local/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from scikit-learn>=0.20.0->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from soundfile>=0.12.1->librosa) (1.15.0)
# Requirement already satisfied: pycparser in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vsaluja2/.local/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/vsaluja2/.local/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vsaluja2/.local/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vsaluja2/.local/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2025.1.31)
# [Default VAE] Epoch 1, Loss: 242631.72
# [Default VAE] Epoch 2, Loss: 824335.53
# [Default VAE] Epoch 3, Loss: 210087.43
# [Default VAE] Epoch 4, Loss: 408948.13
# [Default VAE] Epoch 5, Loss: 149092.20
# [Default VAE] Epoch 6, Loss: 6277701.11
# [Default VAE] Epoch 7, Loss: 103488402390.95
# [Default VAE] Epoch 8, Loss: 6246273437252223610368373647474688.00
# [Default VAE] Epoch 9, Loss: nan
# [Default VAE] Epoch 10, Loss: nan
# [Selective Copying] Epoch 1, Loss: 0.37
# [Selective Copying] Epoch 2, Loss: 0.19
# [Selective Copying] Epoch 3, Loss: 0.09
# [Selective Copying] Epoch 4, Loss: 0.05
# [Selective Copying] Epoch 5, Loss: 0.05
# [Selective Copying] Epoch 6, Loss: 0.05
# [Selective Copying] Epoch 7, Loss: 0.05
# [Selective Copying] Epoch 8, Loss: 0.05
# [Selective Copying] Epoch 9, Loss: 0.05
# [Selective Copying] Epoch 10, Loss: 0.05
# [Autoencoding] Epoch 1, Loss: 244047.40
# [Autoencoding] Epoch 2, Loss: 461599.78
# [Autoencoding] Epoch 3, Loss: 140750.98
# [Autoencoding] Epoch 4, Loss: 90180.87
# [Autoencoding] Epoch 5, Loss: 153041.09
# [Autoencoding] Epoch 6, Loss: 111907.82
# [Autoencoding] Epoch 7, Loss: 99482.89
# [Autoencoding] Epoch 8, Loss: 137967.08
# [Autoencoding] Epoch 9, Loss: 187275.36
# [Autoencoding] Epoch 10, Loss: 142499.73
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Default VAE
dataset = AudioDataset(data_dir=data_path)
dataloader = DataLoader(dataset, batch_size=8, shuffle=True)
model_default = BirdieVAE(input_dim=input_dim)
train(model_default, dataloader, epochs=10)
audio_default = generate_sample(model_default, 'generated_default.wav')
audio_default
# Out:
# [Default VAE] Epoch 1, Loss: 226927.05
# [Default VAE] Epoch 2, Loss: 1106396.48
# [Default VAE] Epoch 3, Loss: 150083.21
# [Default VAE] Epoch 4, Loss: 93533.62
# [Default VAE] Epoch 5, Loss: 66625.69
# [Default VAE] Epoch 6, Loss: 300286.89
# [Default VAE] Epoch 7, Loss: 56551.82
# [Default VAE] Epoch 8, Loss: 50653.98
# [Default VAE] Epoch 9, Loss: 1847869.39
# [Default VAE] Epoch 10, Loss: 43855.49
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Selective Copying
copy_dataset = CopyingDataset(data_dir=data_path)
copy_dataloader = DataLoader(copy_dataset, batch_size=8, shuffle=True)
model_selective = BirdieVAE(input_dim=input_dim)
train_selective_copying(model_selective, copy_dataloader, epochs=10)
audio_selective = generate_sample(model_selective, 'generated_selective.wav')
audio_selective
# Out:
# [Selective Copying] Epoch 1, Loss: 0.36
# [Selective Copying] Epoch 2, Loss: 0.29
# [Selective Copying] Epoch 3, Loss: 0.09
# [Selective Copying] Epoch 4, Loss: 0.06
# [Selective Copying] Epoch 5, Loss: 0.12
# [Selective Copying] Epoch 6, Loss: 0.05
# [Selective Copying] Epoch 7, Loss: 0.05
# [Selective Copying] Epoch 8, Loss: 0.05
# [Selective Copying] Epoch 9, Loss: 0.05
# [Selective Copying] Epoch 10, Loss: 0.05
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Autoencoding
auto_dataset = AutoencodingDataset(data_dir=data_path)
auto_dataloader = DataLoader(auto_dataset, batch_size=8, shuffle=True)
model_auto = BirdieVAE(input_dim=input_dim)
train_autoencoding(model_auto, auto_dataloader, epochs=10)
audio_auto = generate_sample(model_auto, 'generated_autoencoded.wav')
audio_auto
# Out:
# [Autoencoding] Epoch 1, Loss: 233305.63
# [Autoencoding] Epoch 2, Loss: 790038.86
# [Autoencoding] Epoch 3, Loss: 112472.94
# [Autoencoding] Epoch 4, Loss: 71443.47
# [Autoencoding] Epoch 5, Loss: 61487.86
# [Autoencoding] Epoch 6, Loss: 66798.09
# [Autoencoding] Epoch 7, Loss: 59404.82
# [Autoencoding] Epoch 8, Loss: 70528.59
# [Autoencoding] Epoch 9, Loss: 66726.56
# [Autoencoding] Epoch 10, Loss: 52839.60
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
